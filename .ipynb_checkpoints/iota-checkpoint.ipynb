# %%
from iota import Iota
from pprint import pprint

# %%
deposit_addr = 'MPUKMWNFTYFRLJDE9ZWJY9JPKVEIIKDOWANMJIHJJWPOINFRXKVLWOUHFCMCWLO9GAAWDRWGXMTKFCIZDDQTTHNERC'
iota_node = 'https://potato.iotasalad.org:14265'

# %%
iota = Iota(iota_node)

# %%
tss = iota.find_transactions(addresses=[deposit_addr])

# %%
tss
# Out:
# {'hashes': [TransactionHash(b'FWKUHIQHAGSUVNBQFMNA9ZGXLNMPDAPXLRRBKDRROHVUEAJTLPIDXWMUXIEVEFUJECAQRJZGHTFEA9999'),
#   TransactionHash(b'AWMM9OYEZTIPSNMTQRAQOMCVIQIFHMWOEKVNEHLBUVTGSIHLKSXVCXMZTEMSHIGLJFSHZQELNSN9Z9999'),
#   TransactionHash(b'OWLNDFVYKJKXEPPBWZWZBPQXMUCGBFLWGIUPITFFXRXQJZFMEFNAKXXVSQOWVIZFMXJPDKXNLDKCZ9999'),
#   TransactionHash(b'DDXEXBOQLNFSTBDZQANEDGV9YYMIFSDHYOUBWAFFXDAPPZ9YKQFMW9OKI9BVXE9KADQPTHYAOCTM99999'),
#   TransactionHash(b'ZNPSJPZEWDRBGFCLCGYVPNRJ9SWSQORSFEAOFVJI9WXUODXLHJRURJAUZJAFKRJZHYFIVGKGAIQS99999'),
#   TransactionHash(b'BSLWQZAQQLST9VXEYOLSRERXOSNBTCRNH9RKMYYRLRGFFSLHRWRXAPXNNPYJZAOCB9YXAUBUDNQQ99999'),
#   TransactionHash(b'GLROKKVDBAVNQPRSIYOPJNGDEIFFTMJAPWQJL99TTWVZVILYJPVEWHKA9AWNOHCBEM9LEBJUFVPHZ9999'),
#   TransactionHash(b'WSDHIOKNTHJODNIF9PNHSWIYLNJCALSTD9ADHYBUFIUCHJEOBQMOTGNJGTBTBHHWSNO9XWMQVNILA9999'),
#   TransactionHash(b'VNGAWIKRWAE9LUS9AWQIAKPWDHSWEJYOODSDUFRNGWCIGYSNSVNTSKYFPFIUDLPNVXOVFJJHADFSZ9999'),
#   TransactionHash(b'RBIBJBUGDGBDEBEK9KPJZRQZVTJVIFY9NBOGGXWIGYKQDUDHLMYMLDVGJVG9B9ZUSN9CRMNHHKLVZ9999'),
#   TransactionHash(b'JC9HREMQKINHPMJWWIVVVKGDDMDKBZAXAVABSLUWZMGTPATHSPZBBHGLFHYX9WAXOZQDMPUHHTUW99999'),
#   TransactionHash(b'YRJMFORLAMOBJVCDWCAMRUBLUZZAZLXTESNSYLLBJIUCMABS9QHIUIAVPSGBJJCPXRJIWQYNNWJZ99999'),
#   TransactionHash(b'ZIZLXJUODESWIKYXQDDLNFRAHVQMOLDTZJZHTLAG9ZYCLCMJMVHYERXJKDWLBYVLIUZRG9WJVOOU99999'),
#   TransactionHash(b'GRPPOOPFFTGQPKPBC9OFPMQBSKKMDTMZOWXDZ9CQH9IDCTLYBBKUUQFZWMPEAAHULBAHO9FPUQOU99999'),
#   TransactionHash(b'UHT9VKYZSTBVACBLJXFCSHGDGYERXGJWMJFFXKIXQTYBKAZ9JWGZXLDHYWDQCUPGHFDAQUPLJRILZ9999')],
#  'duration': 2}

# %%
bundles = []

# %%
for h in tss["hashes"]:
    b = iota.get_bundles(h)
    bundles.append(b)

# %%
for bundle in bundles:
    for k, v in bundle.items():
        for b in v:
            for transaction in b:
                pprint(transaction.signature_message_fragment.decode())
                break
# Out:
# '{"username": "testuser", "topic": "data"}'
# '{"username": "jonas"}'
# '{"username": "jonas"}'
# '{"username": "testuser"}'
# '{"username": "jonas"}'
# '{"username": "testuser"}'
# '{"username": "jonas"}'
# '{"username": "testuser"}'
# '{"username": "jonas"}'
# '{"username": "jonas"}'
# '{"username": "jonas"}'
# '{"username": "jonas"}'
# '{"username": "jonas"}'
# '{"username": "jonas"}'
# '{"username": "testuser", "topic": "data"}'

# %%
ba = bundles[0]

# %%
ba
# Out:
# {'bundles': [Bundle(*[{'hash_': TransactionHash(b'FWKUHIQHAGSUVNBQFMNA9ZGXLNMPDAPXLRRBKDRROHVUEAJTLPIDXWMUXIEVEFUJECAQRJZGHTFEA9999'),
#            'signature_message_fragment': Fragment(b'...'),
#            'address': Address(b'MPUKMWNFTYFRLJDE9ZWJY9JPKVEIIKDOWANMJIHJJWPOINFRXKVLWOUHFCMCWLO9GAAWDRWGXMTKFCIZD'),
#            'value': 1,
#            'legacy_tag': Tag(b'IRJNITY99999999999999999999'),
#            'timestamp': 1533573456,
#            'current_index': 0,
#            'last_index': 3,
#            'bundle_hash': BundleHash(b'PFSSWLTDBJXLVTEB9QAIJOYGLHOLFWHOTRBCASUZUTPDI9JQGCFEKIRUPCQYZHKCTJAICRDJHUJGR9OPC'),
#            'trunk_transaction_hash': TransactionHash(b'DLSRXRMWUOKZVQHWWPXTQCWQXVMTLLSVCEMWXJCYYKYCIYO9GYEJFYUGLCALTJFYLNZILYR9VJWOA9999'),
#            'branch_transaction_hash': TransactionHash(b'BNIFTVV9AXEVQDRNOVRFMONJDECDGFNRYYMPLAQKXJPCADLBOMLUJOGADDUTXZQXQYDLTVTXRBBQZ9999'),
#            'tag': Tag(b'TRINITY99999999999999999999'),
#            'attachment_timestamp': 1533573481194,
#            'attachment_timestamp_lower_bound': 0,
#            'attachment_timestamp_upper_bound': 3812798742493,
#            'nonce': Nonce(b'NPHGYXDUHLNYWUQNGIJGIHKKS9Y')},
#           {'hash_': TransactionHash(b'DLSRXRMWUOKZVQHWWPXTQCWQXVMTLLSVCEMWXJCYYKYCIYO9GYEJFYUGLCALTJFYLNZILYR9VJWOA9999'),
#            'signature_message_fragment': Fragment(b'...'),
#            'address': Address(b'NVFRGTZZHRUNRTYR9MTPAMFHEHRGTDZDEPHZKDZPGXZSRTF9HRPYZYNLJMOZDKUHRB9MUNWQZHMAWWSVD'),
#            'value': -548,
#            'legacy_tag': Tag(b'TRINITY99999999999999999999'),
#            'timestamp': 1533573456,
#            'current_index': 1,
#            'last_index': 3,
#            'bundle_hash': BundleHash(b'PFSSWLTDBJXLVTEB9QAIJOYGLHOLFWHOTRBCASUZUTPDI9JQGCFEKIRUPCQYZHKCTJAICRDJHUJGR9OPC'),
#            'trunk_transaction_hash': TransactionHash(b'9KDIHWEPUBEWWDGCAVEEXGETPKGJPLJCVJMKK9SQZ9FMMUQTIYDV9WSHQNDQFDMLLXQMQAAANRZPZ9999'),
#            'branch_transaction_hash': TransactionHash(b'BNIFTVV9AXEVQDRNOVRFMONJDECDGFNRYYMPLAQKXJPCADLBOMLUJOGADDUTXZQXQYDLTVTXRBBQZ9999'),
#            'tag': Tag(b'TRINITY99999999999999999999'),
#            'attachment_timestamp': 1533573472134,
#            'attachment_timestamp_lower_bound': 0,
#            'attachment_timestamp_upper_bound': 3812798742493,
#            'nonce': Nonce(b'BNFCA9HCAFMGAGVCEOESHYPRYWC')},
#           {'hash_': TransactionHash(b'9KDIHWEPUBEWWDGCAVEEXGETPKGJPLJCVJMKK9SQZ9FMMUQTIYDV9WSHQNDQFDMLLXQMQAAANRZPZ9999'),
#            'signature_message_fragment': Fragment(b'...'),
#            'address': Address(b'NVFRGTZZHRUNRTYR9MTPAMFHEHRGTDZDEPHZKDZPGXZSRTF9HRPYZYNLJMOZDKUHRB9MUNWQZHMAWWSVD'),
#            'value': 0,
#            'legacy_tag': Tag(b'TRINITY99999999999999999999'),
#            'timestamp': 1533573456,
#            'current_index': 2,
#            'last_index': 3,
#            'bundle_hash': BundleHash(b'PFSSWLTDBJXLVTEB9QAIJOYGLHOLFWHOTRBCASUZUTPDI9JQGCFEKIRUPCQYZHKCTJAICRDJHUJGR9OPC'),
#            'trunk_transaction_hash': TransactionHash(b'G9TILWQSZIRPQOMZLCSWCGDQENWLZSXRHSGCWHVODQGVQWJYQEZIKOCBNWFMYB9UJDGCRVGYQHBO99999'),
#            'branch_transaction_hash': TransactionHash(b'BNIFTVV9AXEVQDRNOVRFMONJDECDGFNRYYMPLAQKXJPCADLBOMLUJOGADDUTXZQXQYDLTVTXRBBQZ9999'),
#            'tag': Tag(b'TRINITY99999999999999999999'),
#            'attachment_timestamp': 1533573472064,
#            'attachment_timestamp_lower_bound': 0,
#            'attachment_timestamp_upper_bound': 3812798742493,
#            'nonce': Nonce(b'ZAUVJINLOWJBWRPYGWZEZLQLHSC')},
#           {'hash_': TransactionHash(b'G9TILWQSZIRPQOMZLCSWCGDQENWLZSXRHSGCWHVODQGVQWJYQEZIKOCBNWFMYB9UJDGCRVGYQHBO99999'),
#            'signature_message_fragment': Fragment(b'...'),
#            'address': Address(b'MHGY9ZFWYKCD9CVYQTLPFSABNAUHWDJ9ZNBALLTH9MCCZSHHDDHTIWCEKTFJNUVHCENVNSSNPYPGAVYGZ'),
#            'value': 547,
#            'legacy_tag': Tag(b'TRINITY99999999999999999999'),
#            'timestamp': 1533573456,
#            'current_index': 3,
#            'last_index': 3,
#            'bundle_hash': BundleHash(b'PFSSWLTDBJXLVTEB9QAIJOYGLHOLFWHOTRBCASUZUTPDI9JQGCFEKIRUPCQYZHKCTJAICRDJHUJGR9OPC'),
#            'trunk_transaction_hash': TransactionHash(b'BNIFTVV9AXEVQDRNOVRFMONJDECDGFNRYYMPLAQKXJPCADLBOMLUJOGADDUTXZQXQYDLTVTXRBBQZ9999'),
#            'branch_transaction_hash': TransactionHash(b'C9TIVAV9SNILRGK9ZTCHSHSJJWG9OFIWILRANTT9SONHSGTRIN9JBRXAJLMPKT9RPBDZQKMXAGEU99999'),
#            'tag': Tag(b'TRINITY99999999999999999999'),
#            'attachment_timestamp': 1533573469455,
#            'attachment_timestamp_lower_bound': 0,
#            'attachment_timestamp_upper_bound': 3812798742493,
#            'nonce': Nonce(b'AHIXMSUKQWTOQEPWIUFDXIOXGWQ')}])]}

# %%
bs = ba["bundles"][0]
first_tryte_pair = bs[0].signature_message_fragment[0] + bs[0].signature_message_fragment[1]
first_tryte_pair
# Out:
# TryteString(b'OD')

# %%
first_tryte_pair = bundle["bundles"][0][0].signature_message_fragment[0] + bundle["bundles"][0][0].signature_message_fragment[1]
first_tryte_pair
# Out:
# TryteString(b'OD')

# %%
from json import loads
import logging
logger = logging.getLogger()

# %%
def extract_json(bundle):
    extracted_json = {}
    first_transaction = bundle["bundles"][0][0]
    first_tryte_pair = first_transaction.signature_message_fragment[0] + first_transaction.signature_message_fragment[1]
    if first_tryte_pair != "OD":
        raise ValueError("No JSON found.")
    for b in bundle["bundles"]:
        for transaction in b:
            fragment = transaction.signature_message_fragment
            try:
                extracted_json.update(loads(fragment.decode()))
            except ValueError as e:
                #logger.exception(e)
                pass
    return extracted_json

# %%
extract_json(ba)
# Out:
# {'username': 'testuser', 'topic': 'data'}
